# %%
import time

print("Welcome to SBI Bank")
time.sleep(2)
print("Please insert your card")
time.sleep(2)
print("card insert successfully, do not remove card")
time.sleep(2)
pwd = 1234
pin = int(input("Please enter your pin"))
balance = 10000
while (True):
  if pin == pwd:
    print("""
                     1==balance
                     2==Account info
                     3==withdraw amount
                     4==deposite balance
                     5==exit""")
    try:
      option = int(input("Please enter your choice"))

    except:
      print("please enter the valid choice")

    if option == 1:
      print(f"your current balance is {balance}")

    elif option ==2:
      print("Name= mayuri kadam")
      print("DOB= 8 july 2002")
      print("Acccount no.= 68596496")

    elif option == 3:
      withdraw_amount = int(input("please enter withdraw amount"))
      balance = balance - withdraw_amount
      print(f"{withdraw_amount} is debited from your account")
      print(f"your updated current balance is {balance}")

    elif option == 4:
      deposite_amount = int(input("please enter withdraw amount"))
      balance = balance + deposite_amount
      print(f"{deposite_amount} is credited in your account")
      print(f"your updated current balance is {balance}")

    elif option == 5:
      print("Thank You...visit again")
      break

  else:
    print("Please enter the valid pin try again")
    break
# Out:
# Welcome to SBI Bank
# Please insert your card
# card insert successfully, do not remove card
# Please enter your pin1234
#
#                      1==balance
#                      2==Account info
#                      3==withdraw amount
#                      4==deposite balance
#                      5==exit
# Please enter your choice1
# your current balance is 10000
#
#                      1==balance
#                      2==Account info
#                      3==withdraw amount
#                      4==deposite balance
#                      5==exit
# Please enter your choice2
# Name= mayuri kadam
# DOB= 8 july 2002
# Acccount no.= 68596496
#
#                      1==balance
#                      2==Account info
#                      3==withdraw amount
#                      4==deposite balance
#                      5==exit
# Please enter your choice3
# please enter withdraw amount5000
# 5000 is debited from your account
# your updated current balance is 5000
#
#                      1==balance
#                      2==Account info
#                      3==withdraw amount
#                      4==deposite balance
#                      5==exit
# Please enter your choice4
# please enter withdraw amount3000
# 3000 is credited in your account
# your updated current balance is 8000
#
#                      1==balance
#                      2==Account info
#                      3==withdraw amount
#                      4==deposite balance
#                      5==exit
# Please enter your choice5
# Thank You...visit again
